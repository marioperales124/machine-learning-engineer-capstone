# %%
import os
import pandas as pd
import numpy as np
import gzip
import json

# %%
path_folder = 'G:\BIG DATA\Recommender System Udacity\Books\data'

# %%
def load_data(file_name, head = 500):
    count = 0
    data = []
    with gzip.open(file_name) as fin:
        for l in fin:
            d = json.loads(l)
            count += 1
            data.append(d)
            
            # break if reaches the 100th line
            if (head is not None) and (count > head):
                break
    return data

# %%
book_genres_path = os.path.join(path_folder, 'goodreads_book_genres_initial.json.gz')
book_work_path = os.path.join(path_folder, 'goodreads_book_works.json.gz')
book_authors_path = os.path.join(path_folder, 'goodreads_book_authors.json.gz')
books_path = os.path.join(path_folder, 'goodreads_books.json.gz')


user_maps_path = os.path.join(path_folder, 'user_id_map.csv') 
book_maps_path = os.path.join(path_folder, 'book_id_map.csv')
interactions_path = os.path.join(path_folder, 'goodreads_interactions.csv')

# %%
val = None

# %%
book_genres_data = load_data(book_genres_path, val)
#book_work_data = load_data(book_work_path, val)
book_authors_data = load_data(book_authors_path, val)
books_data = load_data(books_path, val)

# %% [markdown]
# ### Book data

# %%
books_df = pd.DataFrame.from_dict(books_data)

# %%
books_df.columns

# %%
books_df['authors'][:50][45]

# %%
selected_vars_book = ['book_id', 'is_ebook', 'average_rating', 'num_pages',
                      'authors', 'publication_year', 'text_reviews_count',
                      'ratings_count']

books_df = books_df[selected_vars_book]

selected_vars_book_names = ['book_id', 'is_ebook', 'average_rating_book', 'num_pages',
                          'authors', 'publication_year', 'text_reviews_count_book',
                          'ratings_count_book']

books_df.columns = selected_vars_book_names

# %%
def get_author_id(l):
    try:
        for d in l:
            if d['role'] == '':
                return str(d['author_id'])
        return str(l[0]['author_id'])
    except IndexError:
        return 'Anonymous'

# %%
books_df['author_id'] = books_df['authors'].apply(lambda l: get_author_id(l))

# %% [markdown]
# ### Interacciones

# %%
interactions = pd.read_csv(interactions_path, nrows=val)

# %%
print(interactions.user_id.nunique()) 
print(interactions.book_id.nunique()) 
print(interactions.user_id.nunique() * interactions.book_id.nunique())
print(len(interactions))
# Out:
# 228
# 59139
# 13483692
# 100000

# %% [markdown]
# ### Authors data

# %%
book_authors_data
# Out:
# [{'average_rating': '3.98',
#   'author_id': '604031',
#   'text_reviews_count': '7',
#   'name': 'Ronald J. Fields',
#   'ratings_count': '49'},
#  {'average_rating': '4.08',
#   'author_id': '626222',
#   'text_reviews_count': '28716',
#   'name': 'Anita Diamant',
#   'ratings_count': '546796'},
#  {'average_rating': '3.92',
#   'author_id': '10333',
#   'text_reviews_count': '5075',
#   'name': 'Barbara Hambly',
#   'ratings_count': '122118'},
#  {'average_rating': '3.68',
#   'author_id': '9212',
#   'text_reviews_count': '36262',
#   'name': 'Jennifer Weiner',
#   'ratings_count': '888522'},
#  {'average_rating': '3.82',
#   'author_id': '149918',
#   'text_reviews_count': '96',
#   'name': 'Nigel Pennick',
#   'ratings_count': '1740'},
#  {'average_rating': '3.89',
#   'author_id': '3041852',
#   'text_reviews_count': '85',
#   'name': 'Alfred J. Church',
#   'ratings_count': '947'},
#  {'average_rating': '4.17',
#   'author_id': '215594',
#   'text_reviews_count': '6',
#   'name': 'Michael Halberstam',
#   'ratings_count': '23'},
#  {'average_rating': '4.18',
#   'author_id': '19158',
#   'text_reviews_count': '486',
#   'name': 'Rachel Roberts',
#   'ratings_count': '13677'},
#  {'average_rating': '3.99',
#   'author_id': '5807700',
#   'text_reviews_count': '986',
#   'name': 'V.L. Locey',
#   'ratings_count': '3130'},
#  {'average_rating': '3.48',
#   'author_id': '2983296',
#   'text_reviews_count': '824',
#   'name': 'Anton Szandor LaVey',
#   'ratings_count': '12628'},
#  {'average_rating': '3.76',
#   'author_id': '40075',
#   'text_reviews_count': '396',
#   'name': 'Kenneth Anger',
#   'ratings_count': '5255'},
#  {'average_rating': '3.86',
#   'author_id': '37778',
#   'text_reviews_count': '616',
#   'name': 'Bernard Knight',
#   'ratings_count': '7836'},
#  {'average_rating': '3.95',
#   'author_id': '242185',
#   'text_reviews_count': '2906',
#   'name': 'Carolyn Haines',
#   'ratings_count': '42549'},
#  {'average_rating': '4.00',
#   'author_id': '27397',
#   'text_reviews_count': '4231',
#   'name': 'Benjamin Hoff',
#   'ratings_count': '104975'},
#  {'average_rating': '3.54',
#   'author_id': '35259',
#   'text_reviews_count': '81',
#   'name': 'Christopher Ross',
#   'ratings_count': '420'},
#  {'average_rating': '3.84',
#   'author_id': '3083854',
#   'text_reviews_count': '9732',
#   'name': 'Tom Wolfe',
#   'ratings_count': '210744'},
#  {'average_rating': '3.92',
#   'author_id': '39054',
#   'text_reviews_count': '3251',
#   'name': 'Don Piper',
#   'ratings_count': '71959'},
#  {'average_rating': '3.96',
#   'author_id': '11099',
#   'text_reviews_count': '5313',
#   'name': 'Cecil Murphey',
#   'ratings_count': '86128'},
#  {'average_rating': '4.29',
#   'author_id': '4862',
#   'text_reviews_count': '3992',
#   'name': 'Randy Alcorn',
#   'ratings_count': '56585'},
#  {'average_rating': '3.99',
#   'author_id': '137561',
#   'text_reviews_count': '12146',
#   'name': 'Jennifer L. Holm',
#   'ratings_count': '128152'},
#  {'average_rating': '4.06',
#   'author_id': '5411',
#   'text_reviews_count': '8642',
#   'name': 'Cynthia Rylant',
#   'ratings_count': '96780'},
#  {'average_rating': '3.84',
#   'author_id': '4092328',
#   'text_reviews_count': '97',
#   'name': 'Margot Hovley',
#   'ratings_count': '318'},
#  {'average_rating': '4.14',
#   'author_id': '75424',
#   'text_reviews_count': '7',
#   'name': 'Wayne Kinsey',
#   'ratings_count': '71'},
#  {'average_rating': '3.66',
#   'author_id': '1357577',
#   'text_reviews_count': '1889',
#   'name': 'Francoise Sagan',
#   'ratings_count': '28688'},
#  {'average_rating': '4.01',
#   'author_id': '3389',
#   'text_reviews_count': '367487',
#   'name': 'Stephen King',
#   'ratings_count': '10666719'},
#  {'average_rating': '4.10',
#   'author_id': '105602',
#   'text_reviews_count': '1916',
#   'name': 'Edward Herrmann',
#   'ratings_count': '7201'},
#  {'average_rating': '4.14',
#   'author_id': '31308',
#   'text_reviews_count': '127',
#   'name': 'Peter Maass',
#   'ratings_count': '1194'},
#  {'average_rating': '3.89',
#   'author_id': '50873',
#   'text_reviews_count': '30755',
#   'name': 'L.J. Smith',
#   'ratings_count': '919399'},
#  {'average_rating': '3.82',
#   'author_id': '232533',
#   'text_reviews_count': '58',
#   'name': 'Anne Emmert',
#   'ratings_count': '436'},
#  {'average_rating': '4.50',
#   'author_id': '166520',
#   'text_reviews_count': '1',
#   'name': 'Christopher Michael McDonough',
#   'ratings_count': '2'},
#  {'average_rating': '4.06',
#   'author_id': '166517',
#   'text_reviews_count': '17',
#   'name': 'Richard E. Prior',
#   'ratings_count': '168'},
#  {'average_rating': '4.50',
#   'author_id': '3958428',
#   'text_reviews_count': '1',
#   'name': 'Mark Jackson Stansbury',
#   'ratings_count': '2'},
#  {'average_rating': '4.50',
#   'author_id': '3958429',
#   'text_reviews_count': '1',
#   'name': 'Mark Stansbury',
#   'ratings_count': '2'},
#  {'average_rating': '0.0',
#   'author_id': '6536612',
#   'text_reviews_count': '1',
#   'name': 'Zabrina Murray',
#   'ratings_count': '0'},
#  {'average_rating': '4.03',
#   'author_id': '15585',
#   'text_reviews_count': '158',
#   'name': 'James Russell Lowell',
#   'ratings_count': '1464'},
#  {'average_rating': '4.05',
#   'author_id': '5054653',
#   'text_reviews_count': '37',
#   'name': 'Lisa Mills',
#   'ratings_count': '218'},
#  {'average_rating': '4.70',
#   'author_id': '7326076',
#   'text_reviews_count': '15',
#   'name': 'Zhang  Yun',
#   'ratings_count': '23'},
#  {'average_rating': '3.63',
#   'author_id': '15104629',
#   'text_reviews_count': '66',
#   'name': 'David  Blake',
#   'ratings_count': '473'},
#  {'average_rating': '3.48',
#   'author_id': '14425713',
#   'text_reviews_count': '23',
#   'name': 'David J. Ashton',
#   'ratings_count': '200'},
#  {'average_rating': '4.25',
#   'author_id': '51229',
#   'text_reviews_count': '8761',
#   'name': 'John  Williams',
#   'ratings_count': '72020'},
#  {'average_rating': '3.72',
#   'author_id': '110982',
#   'text_reviews_count': '2172',
#   'name': 'Peter Cameron',
#   'ratings_count': '15208'},
#  {'average_rating': '4.11',
#   'author_id': '5768434',
#   'text_reviews_count': '416',
#   'name': 'Stefano Tummolini',
#   'ratings_count': '2133'},
#  {'average_rating': '4.25',
#   'author_id': '2994299',
#   'text_reviews_count': '284',
#   'name': 'mHmd`ly frwGy',
#   'ratings_count': '4602'},
#  {'average_rating': '4.10',
#   'author_id': '5360266',
#   'text_reviews_count': '6895',
#   'name': 'Carrie Ann Ryan',
#   'ratings_count': '62789'},
#  {'average_rating': '3.56',
#   'author_id': '190988',
#   'text_reviews_count': '214',
#   'name': 'Margaret Yorke',
#   'ratings_count': '1813'},
#  {'average_rating': '4.13',
#   'author_id': '8289606',
#   'text_reviews_count': '70',
#   'name': 'Nikki Faye',
#   'ratings_count': '258'},
#  {'average_rating': '4.10',
#   'author_id': '1265',
#   'text_reviews_count': '127817',
#   'name': 'Jane Austen',
#   'ratings_count': '4693826'},
#  {'average_rating': '4.11',
#   'author_id': '8551671',
#   'text_reviews_count': '1',
#   'name': 'Lindsey Schussman',
#   'ratings_count': '9'},
#  {'average_rating': '4.25',
#   'author_id': '17038441',
#   'text_reviews_count': '1',
#   'name': 'Raina Palmatier',
#   'ratings_count': '4'},
#  {'average_rating': '3.87',
#   'author_id': '589328',
#   'text_reviews_count': '7',
#   'name': 'Larry Shles',
#   'ratings_count': '31'},
#  {'average_rating': '4.10',
#   'author_id': '2608283',
#   'text_reviews_count': '7',
#   'name': 'Bradley L. Winch',
#   'ratings_count': '30'},
#  {'average_rating': '4.13',
#   'author_id': '16667',
#   'text_reviews_count': '39262',
#   'name': 'Isaac Asimov',
#   'ratings_count': '1533093'},
#  {'average_rating': '3.89',
#   'author_id': '44554',
#   'text_reviews_count': '9551',
#   'name': 'Scott Brick',
#   'ratings_count': '82004'},
#  {'average_rating': '3.82',
#   'author_id': '1455',
#   'text_reviews_count': '56698',
#   'name': 'Ernest Hemingway',
#   'ratings_count': '1619036'},
#  {'average_rating': '3.97',
#   'author_id': '1004238',
#   'text_reviews_count': '2620',
#   'name': 'Will Patton',
#   'ratings_count': '9202'},
#  {'average_rating': '3.83',
#   'author_id': '90411',
#   'text_reviews_count': '1223',
#   'name': 'Kit Tunstall',
#   'ratings_count': '8402'},
#  {'average_rating': '4.10',
#   'author_id': '14356708',
#   'text_reviews_count': '612',
#   'name': 'Kit Fawkes',
#   'ratings_count': '3136'},
#  {'average_rating': '1.00',
#   'author_id': '15425909',
#   'text_reviews_count': '1',
#   'name': 'Esra Bahadir Cesar',
#   'ratings_count': '1'},
#  {'average_rating': '4.19',
#   'author_id': '53167',
#   'text_reviews_count': '5',
#   'name': 'H. Kent Baker',
#   'ratings_count': '43'},
#  {'average_rating': '3.75',
#   'author_id': '13536229',
#   'text_reviews_count': '1',
#   'name': 'Victor Ricciardi',
#   'ratings_count': '4'},
#  {'average_rating': '4.24',
#   'author_id': '6475486',
#   'text_reviews_count': '4',
#   'name': 'Freddy Jackson Brown',
#   'ratings_count': '17'},
#  {'average_rating': '4.00',
#   'author_id': '14856310',
#   'text_reviews_count': '2',
#   'name': 'Duncan Gillard',
#   'ratings_count': '4'},
#  {'average_rating': '4.10',
#   'author_id': '14253',
#   'text_reviews_count': '407',
#   'name': 'Steven C. Hayes',
#   'ratings_count': '5886'},
#  {'average_rating': '3.94',
#   'author_id': '100084',
#   'text_reviews_count': '184',
#   'name': 'Paula Rabinowitz',
#   'ratings_count': '1743'},
#  {'average_rating': '3.62',
#   'author_id': '47231',
#   'text_reviews_count': '1790',
#   'name': 'Stacey Ballis',
#   'ratings_count': '13842'},
#  {'average_rating': '3.77',
#   'author_id': '3330668',
#   'text_reviews_count': '10129',
#   'name': 'Jenika Snow',
#   'ratings_count': '112695'},
#  {'average_rating': '4.02',
#   'author_id': '5804912',
#   'text_reviews_count': '80',
#   'name': 'Elizabeth Guizzetti',
#   'ratings_count': '111'},
#  {'average_rating': '3.84',
#   'author_id': '2787558',
#   'text_reviews_count': '5',
#   'name': 'Ira Severin',
#   'ratings_count': '43'},
#  {'average_rating': '3.94',
#   'author_id': '834674',
#   'text_reviews_count': '2',
#   'name': 'Sean M. Theriault',
#   'ratings_count': '34'},
#  {'average_rating': '3.50',
#   'author_id': '17180082',
#   'text_reviews_count': '1',
#   'name': 'Queen Rex',
#   'ratings_count': '4'},
#  {'average_rating': '3.46',
#   'author_id': '285644',
#   'text_reviews_count': '32',
#   'name': 'Ian Botham',
#   'ratings_count': '413'},
#  {'average_rating': '3.44',
#   'author_id': '337108',
#   'text_reviews_count': '105',
#   'name': 'Margaret Doody',
#   'ratings_count': '1134'},
#  {'average_rating': '3.29',
#   'author_id': '4585413',
#   'text_reviews_count': '54',
#   'name': 'Rosalia Coci',
#   'ratings_count': '558'},
#  {'average_rating': '3.40',
#   'author_id': '1093599',
#   'text_reviews_count': '33',
#   'name': 'Beppe Benvenuto',
#   'ratings_count': '248'},
#  {'average_rating': '4.18',
#   'author_id': '14843595',
#   'text_reviews_count': '18',
#   'name': 'B. Batregzedmaa',
#   'ratings_count': '82'},
#  {'average_rating': '3.85',
#   'author_id': '169159',
#   'text_reviews_count': '86',
#   'name': 'Mandy Stanley',
#   'ratings_count': '657'},
#  {'average_rating': '3.84',
#   'author_id': '4918',
#   'text_reviews_count': '1149',
#   'name': 'Robert Burleigh',
#   'ratings_count': '4560'},
#  {'average_rating': '3.37',
#   'author_id': '3274315',
#   'text_reviews_count': '4',
#   'name': 'Florence Dupre la Tour',
#   'ratings_count': '62'},
#  {'average_rating': '3.71',
#   'author_id': '89445',
#   'text_reviews_count': '120',
#   'name': 'Terence Conran',
#   'ratings_count': '946'},
#  {'average_rating': '3.61',
#   'author_id': '1528477',
#   'text_reviews_count': '4',
#   'name': 'Roger Dubern',
#   'ratings_count': '18'},
#  {'average_rating': '3.97',
#   'author_id': '106170',
#   'text_reviews_count': '30',
#   'name': 'John McGowan',
#   'ratings_count': '434'},
#  {'average_rating': '4.22',
#   'author_id': '42820',
#   'text_reviews_count': '89',
#   'name': 'Hugh Johnson',
#   'ratings_count': '1525'},
#  {'average_rating': '3.84',
#   'author_id': '8070',
#   'text_reviews_count': '30',
#   'name': 'Isser Woloch',
#   'ratings_count': '393'},
#  {'average_rating': '3.71',
#   'author_id': '650106',
#   'text_reviews_count': '2',
#   'name': 'Gregory S. Brown',
#   'ratings_count': '14'},
#  {'average_rating': '2.50',
#   'author_id': '15036621',
#   'text_reviews_count': '3',
#   'name': 'ndr brhny mrnd',
#   'ratings_count': '2'},
#  {'average_rating': '3.61',
#   'author_id': '3258',
#   'text_reviews_count': '293',
#   'name': 'Jeremy Black',
#   'ratings_count': '2082'},
#  {'average_rating': '3.80',
#   'author_id': '5533990',
#   'text_reviews_count': '4',
#   'name': 'Claire Fay',
#   'ratings_count': '15'},
#  {'average_rating': '3.53',
#   'author_id': '1493903',
#   'text_reviews_count': '13',
#   'name': 'Arun Maira',
#   'ratings_count': '62'},
#  {'average_rating': '3.96',
#   'author_id': '5395324',
#   'text_reviews_count': '84',
#   'name': 'Melanie Cusick-Jones',
#   'ratings_count': '172'},
#  {'average_rating': '3.92',
#   'author_id': '526866',
#   'text_reviews_count': '269',
#   'name': 'Neville Astley',
#   'ratings_count': '3693'},
#  {'average_rating': '3.55',
#   'author_id': '162140',
#   'text_reviews_count': '4',
#   'name': 'Praveen Gupta',
#   'ratings_count': '73'},
#  {'average_rating': '3.44',
#   'author_id': '2742419',
#   'text_reviews_count': '1',
#   'name': 'Dipak Jain',
#   'ratings_count': '18'},
#  {'average_rating': '3.87',
#   'author_id': '7314532',
#   'text_reviews_count': '10328',
#   'name': 'Sally Green',
#   'ratings_count': '57920'},
#  {'average_rating': '3.91',
#   'author_id': '6217503',
#   'text_reviews_count': '2289',
#   'name': 'Maya Cross',
#   'ratings_count': '41075'},
#  {'average_rating': '4.02',
#   'author_id': '16073',
#   'text_reviews_count': '1079',
#   'name': 'Robert Walser',
#   'ratings_count': '10359'},
#  {'average_rating': '4.20',
#   'author_id': '3484503',
#   'text_reviews_count': '12',
#   'name': 'Daniele Pantano',
#   'ratings_count': '91'},
#  {'average_rating': '3.96',
#   'author_id': '367928',
#   'text_reviews_count': '39',
#   'name': 'James Reidel',
#   'ratings_count': '184'},
#  {'average_rating': '3.77',
#   'author_id': '1028358',
#   'text_reviews_count': '3',
#   'name': 'Reto Sorg',
#   'ratings_count': '43'},
#  {'average_rating': '3.97',
#   'author_id': '123715',
#   'text_reviews_count': '115724',
#   'name': 'Agatha Christie',
#   'ratings_count': '2559239'},
#  {'average_rating': '3.68',
#   'author_id': '552417',
#   'text_reviews_count': '422',
#   'name': 'Emilia Fox',
#   'ratings_count': '1712'},
#  {'average_rating': '4.20',
#   'author_id': '11593',
#   'text_reviews_count': '5545',
#   'name': 'Beatrix Potter',
#   'ratings_count': '336443'},
#  {'average_rating': '5.00',
#   'author_id': '15973929',
#   'text_reviews_count': '1',
#   'name': 'Harry Deane Willmott',
#   'ratings_count': '1'},
#  {'average_rating': '4.36',
#   'author_id': '15079113',
#   'text_reviews_count': '64',
#   'name': 'Joan Carney',
#   'ratings_count': '88'},
#  {'average_rating': '4.04',
#   'author_id': '1938',
#   'text_reviews_count': '7881',
#   'name': 'Friedrich Nietzsche',
#   'ratings_count': '250672'},
#  {'average_rating': '4.00',
#   'author_id': '603349',
#   'text_reviews_count': '200',
#   'name': 'drywsh ashwry',
#   'ratings_count': '2403'},
#  {'average_rating': '3.77',
#   'author_id': '13607545',
#   'text_reviews_count': '2762',
#   'name': 'Sadegh Hedayat',
#   'ratings_count': '51537'},
#  {'average_rating': '3.80',
#   'author_id': '13658169',
#   'text_reviews_count': '10',
#   'name': 'Randall S. Davis',
#   'ratings_count': '15'},
#  {'average_rating': '3.50',
#   'author_id': '1533165',
#   'text_reviews_count': '231',
#   'name': 'W.J. Burley',
#   'ratings_count': '1873'},
#  {'average_rating': '4.30',
#   'author_id': '6938130',
#   'text_reviews_count': '44',
#   'name': 'Shay Ray Stevens',
#   'ratings_count': '125'},
#  {'average_rating': '2.86',
#   'author_id': '1051586',
#   'text_reviews_count': '67',
#   'name': 'Elaine Szewczyk',
#   'ratings_count': '256'},
#  {'average_rating': '3.68',
#   'author_id': '169662',
#   'text_reviews_count': '279',
#   'name': 'Duncan Rouleau',
#   'ratings_count': '4329'},
#  {'average_rating': '3.46',
#   'author_id': '23519',
#   'text_reviews_count': '832',
#   'name': 'Joe Casey',
#   'ratings_count': '8611'},
#  {'average_rating': '3.95',
#   'author_id': '18119',
#   'text_reviews_count': '3099',
#   'name': 'Joe Kelly',
#   'ratings_count': '39295'},
#  {'average_rating': '3.74',
#   'author_id': '29688',
#   'text_reviews_count': '835',
#   'name': 'Steven T. Seagle',
#   'ratings_count': '7649'},
#  {'average_rating': '4.09',
#   'author_id': '5193034',
#   'text_reviews_count': '11505',
#   'name': 'Tracey Garvis-Graves',
#   'ratings_count': '88486'},
#  {'average_rating': '3.66',
#   'author_id': '5346805',
#   'text_reviews_count': '126',
#   'name': 'Serena Lauzi',
#   'ratings_count': '591'},
#  {'average_rating': '3.88',
#   'author_id': '146147',
#   'text_reviews_count': '109',
#   'name': 'M. Ageyev',
#   'ratings_count': '1540'},
#  {'average_rating': '4.06',
#   'author_id': '37450',
#   'text_reviews_count': '12304',
#   'name': 'Ed Brubaker',
#   'ratings_count': '233336'},
#  {'average_rating': '4.53',
#   'author_id': '6601585',
#   'text_reviews_count': '3',
#   'name': 'Spike Brown',
#   'ratings_count': '15'},
#  {'average_rating': '3.46',
#   'author_id': '618935',
#   'text_reviews_count': '12',
#   'name': 'Gerald L. Gutek',
#   'ratings_count': '178'},
#  {'average_rating': '3.87',
#   'author_id': '14771610',
#   'text_reviews_count': '3',
#   'name': 'mHmd Th',
#   'ratings_count': '23'},
#  {'average_rating': '3.85',
#   'author_id': '7083555',
#   'text_reviews_count': '2528',
#   'name': 'John  Langan',
#   'ratings_count': '24550'},
#  {'average_rating': '3.88',
#   'author_id': '41194',
#   'text_reviews_count': '1251',
#   'name': 'Judith Tarr',
#   'ratings_count': '29656'},
#  {'average_rating': '4.05',
#   'author_id': '16209952',
#   'text_reviews_count': '8',
#   'name': 'Jason Delgado',
#   'ratings_count': '19'},
#  {'average_rating': '3.87',
#   'author_id': '853385',
#   'text_reviews_count': '70',
#   'name': 'Chris  Martin',
#   'ratings_count': '758'},
#  {'average_rating': '3.63',
#   'author_id': '3111153',
#   'text_reviews_count': '5182',
#   'name': 'Catherine McKenzie',
#   'ratings_count': '41739'},
#  {'average_rating': '3.68',
#   'author_id': '6462472',
#   'text_reviews_count': '384',
#   'name': 'Amy Raby',
#   'ratings_count': '3698'},
#  {'average_rating': '4.23',
#   'author_id': '6480066',
#   'text_reviews_count': '388',
#   'name': "Lisa Clark O'Neill",
#   'ratings_count': '3353'},
#  {'average_rating': '3.84',
#   'author_id': '16272',
#   'text_reviews_count': '12749',
#   'name': 'Michel Faber',
#   'ratings_count': '174393'},
#  {'average_rating': '4.00',
#   'author_id': '2313236',
#   'text_reviews_count': '1',
#   'name': 'Leslie Gent',
#   'ratings_count': '1'},
#  {'average_rating': '4.12',
#   'author_id': '293603',
#   'text_reviews_count': '8949',
#   'name': 'Heather Brewer',
#   'ratings_count': '127881'},
#  {'average_rating': '3.61',
#   'author_id': '9343',
#   'text_reviews_count': '7464',
#   'name': 'Kate Mosse',
#   'ratings_count': '83451'},
#  {'average_rating': '3.48',
#   'author_id': '410348',
#   'text_reviews_count': '98',
#   'name': 'Kathleen Bryan',
#   'ratings_count': '752'},
#  {'average_rating': '3.87',
#   'author_id': '207766',
#   'text_reviews_count': '979',
#   'name': 'Thomas F. Monteleone',
#   'ratings_count': '14096'},
#  {'average_rating': '4.24',
#   'author_id': '7034616',
#   'text_reviews_count': '25',
#   'name': 'Byron Goines',
#   'ratings_count': '42'},
#  {'average_rating': '3.46',
#   'author_id': '7205180',
#   'text_reviews_count': '12',
#   'name': 'Mei Bei Er',
#   'ratings_count': '82'},
#  {'average_rating': '3.44',
#   'author_id': '5166301',
#   'text_reviews_count': '11',
#   'name': 'ehmyepye``r',
#   'ratings_count': '80'},
#  {'average_rating': '3.69',
#   'author_id': '3482882',
#   'text_reviews_count': '196',
#   'name': 'esiiywefinghling',
#   'ratings_count': '1349'},
#  {'average_rating': '3.95',
#   'author_id': '14425920',
#   'text_reviews_count': '3361',
#   'name': 'Chance Carter',
#   'ratings_count': '13035'},
#  {'average_rating': '3.98',
#   'author_id': '5031025',
#   'text_reviews_count': '10600',
#   'name': 'Anton Chekhov',
#   'ratings_count': '190472'},
#  {'average_rating': '3.75',
#   'author_id': '7066263',
#   'text_reviews_count': '56',
#   'name': 'Wakoh Honna',
#   'ratings_count': '1382'},
#  {'average_rating': '3.76',
#   'author_id': '8444911',
#   'text_reviews_count': '51',
#   'name': 'Honna Wakou (Ben Ming  wakou)',
#   'ratings_count': '1275'},
#  {'average_rating': '4.08',
#   'author_id': '51308',
#   'text_reviews_count': '50',
#   'name': 'Bill Guggenheim',
#   'ratings_count': '737'},
#  {'average_rating': '4.08',
#   'author_id': '51307',
#   'text_reviews_count': '48',
#   'name': 'Judy Guggenheim',
#   'ratings_count': '734'},
#  {'average_rating': '3.58',
#   'author_id': '241450',
#   'text_reviews_count': '894',
#   'name': 'Rebecca Mead',
#   'ratings_count': '4176'},
#  {'average_rating': '3.95',
#   'author_id': '20185',
#   'text_reviews_count': '78',
#   'name': 'Mike   Evans',
#   'ratings_count': '686'},
#  {'average_rating': '3.89',
#   'author_id': '1540277',
#   'text_reviews_count': '17',
#   'name': 'Katia Novet Saint-Lot',
#   'ratings_count': '45'},
#  {'average_rating': '3.77',
#   'author_id': '526216',
#   'text_reviews_count': '40',
#   'name': 'Dimitrea Tokunbo',
#   'ratings_count': '86'},
#  {'average_rating': '4.00',
#   'author_id': '8354390',
#   'text_reviews_count': '1',
#   'name': 'InLoveWithARockStar',
#   'ratings_count': '1'},
#  {'average_rating': '4.27',
#   'author_id': '4577517',
#   'text_reviews_count': '18',
#   'name': 'Jonathan Ashley',
#   'ratings_count': '41'},
#  {'average_rating': '3.70',
#   'author_id': '7355144',
#   'text_reviews_count': '221',
#   'name': 'J.S. Wilder',
#   'ratings_count': '1290'},
#  {'average_rating': '3.89',
#   'author_id': '81563',
#   'text_reviews_count': '629',
#   'name': 'Jerry Siegel',
#   'ratings_count': '5425'},
#  {'average_rating': '3.94',
#   'author_id': '89537',
#   'text_reviews_count': '396',
#   'name': 'Joe Shuster',
#   'ratings_count': '3266'},
#  {'average_rating': '3.89',
#   'author_id': '2953781',
#   'text_reviews_count': '7637',
#   'name': 'Andrew  Grey',
#   'ratings_count': '65157'},
#  {'average_rating': '4.83',
#   'author_id': '14241994',
#   'text_reviews_count': '6',
#   'name': 'Giuseppe Badaracco',
#   'ratings_count': '24'},
#  {'average_rating': '3.89',
#   'author_id': '4018722',
#   'text_reviews_count': '21208',
#   'name': 'Beth Revis',
#   'ratings_count': '195664'},
#  {'average_rating': '3.62',
#   'author_id': '1015982',
#   'text_reviews_count': '7',
#   'name': 'Yuu Asami',
#   'ratings_count': '128'},
#  {'average_rating': '3.70',
#   'author_id': '5806527',
#   'text_reviews_count': '34',
#   'name': 'Andres Vidal',
#   'ratings_count': '149'},
#  {'average_rating': '4.10',
#   'author_id': '22458',
#   'text_reviews_count': '1510',
#   'name': 'Machado de Assis',
#   'ratings_count': '41668'},
#  {'average_rating': '3.78',
#   'author_id': '422353',
#   'text_reviews_count': '560',
#   'name': '`bdllh khwthry',
#   'ratings_count': '4236'},
#  {'average_rating': '3.72',
#   'author_id': '1916427',
#   'text_reviews_count': '974',
#   'name': 'Blake Charlton',
#   'ratings_count': '9427'},
#  {'average_rating': '3.69',
#   'author_id': '78057',
#   'text_reviews_count': '15',
#   'name': 'Gunnar Kopperud',
#   'ratings_count': '64'},
#  {'average_rating': '4.01',
#   'author_id': '843200',
#   'text_reviews_count': '14257',
#   'name': 'Oliver Sacks',
#   'ratings_count': '255736'},
#  {'average_rating': '3.52',
#   'author_id': '5819662',
#   'text_reviews_count': '23',
#   'name': 'Jesper Ersgard',
#   'ratings_count': '112'},
#  {'average_rating': '3.98',
#   'author_id': '617249',
#   'text_reviews_count': '381',
#   'name': 'Gregory L. Norris',
#   'ratings_count': '1804'},
#  {'average_rating': '4.32',
#   'author_id': '5474715',
#   'text_reviews_count': '21',
#   'name': 'Elise Desaulniers',
#   'ratings_count': '118'},
#  {'average_rating': '4.00',
#   'author_id': '12577',
#   'text_reviews_count': '34835',
#   'name': 'Douglas Preston',
#   'ratings_count': '590043'},
#  {'average_rating': '4.00',
#   'author_id': '11091',
#   'text_reviews_count': '31945',
#   'name': 'Lincoln Child',
#   'ratings_count': '571889'},
#  {'average_rating': '3.25',
#   'author_id': '4738706',
#   'text_reviews_count': '2',
#   'name': 'Micky Livingston',
#   'ratings_count': '8'},
#  {'average_rating': '4.02',
#   'author_id': '6564404',
#   'text_reviews_count': '34',
#   'name': "'bw  dhr lqlmwny",
#   'ratings_count': '212'},
#  {'average_rating': '3.30',
#   'author_id': '635213',
#   'text_reviews_count': '35',
#   'name': 'Feridun Zaimoglu',
#   'ratings_count': '398'},
#  {'average_rating': '3.81',
#   'author_id': '335695',
#   'text_reviews_count': '511',
#   'name': 'Jeff Mann',
#   'ratings_count': '2197'},
#  {'average_rating': '3.75',
#   'author_id': '7810887',
#   'text_reviews_count': '1',
#   'name': 'Julian Davis',
#   'ratings_count': '4'},
#  {'average_rating': '4.19',
#   'author_id': '14965',
#   'text_reviews_count': '11103',
#   'name': 'Garth Ennis',
#   'ratings_count': '377440'},
#  {'average_rating': '3.58',
#   'author_id': '3188368',
#   'text_reviews_count': '32',
#   'name': 'Tomas Aira',
#   'ratings_count': '231'},
#  {'average_rating': '3.81',
#   'author_id': '131836',
#   'text_reviews_count': '103',
#   'name': 'Keith Burns',
#   'ratings_count': '1742'},
#  {'average_rating': '4.19',
#   'author_id': '7507599',
#   'text_reviews_count': '10',
#   'name': 'Matt Martin',
#   'ratings_count': '57'},
#  {'average_rating': '3.54',
#   'author_id': '24594',
#   'text_reviews_count': '205',
#   'name': 'Mike Wolfer',
#   'ratings_count': '2915'},
#  {'average_rating': '3.88',
#   'author_id': '5757470',
#   'text_reviews_count': '176',
#   'name': 'Steven Luna',
#   'ratings_count': '858'},
#  {'average_rating': '3.92',
#   'author_id': '4349351',
#   'text_reviews_count': '131',
#   'name': 'Jeremy D. Brooks',
#   'ratings_count': '545'},
#  {'average_rating': '3.85',
#   'author_id': '13195',
#   'text_reviews_count': '2578',
#   'name': 'Marion Dane Bauer',
#   'ratings_count': '24137'},
#  {'average_rating': '4.29',
#   'author_id': '30853',
#   'text_reviews_count': '229',
#   'name': 'Stan Tekiela',
#   'ratings_count': '2312'},
#  {'average_rating': '3.84',
#   'author_id': '6868661',
#   'text_reviews_count': '127',
#   'name': 'Adam Rakunas',
#   'ratings_count': '451'},
#  {'average_rating': '3.72',
#   'author_id': '14155472',
#   'text_reviews_count': '1278',
#   'name': 'Simon Spurrier',
#   'ratings_count': '12378'},
#  {'average_rating': '3.44',
#   'author_id': '8224446',
#   'text_reviews_count': '12',
#   'name': 'Fernando Heinz',
#   'ratings_count': '108'},
#  {'average_rating': '3.45',
#   'author_id': '1251983',
#   'text_reviews_count': '46',
#   'name': 'Rafael Ortiz',
#   'ratings_count': '423'},
#  {'average_rating': '3.73',
#   'author_id': '5808419',
#   'text_reviews_count': '28',
#   'name': 'DigiKore Studios',
#   'ratings_count': '409'},
#  {'average_rating': '3.75',
#   'author_id': '4346284',
#   'text_reviews_count': '64',
#   'name': 'Jaymes Reed',
#   'ratings_count': '332'},
#  {'average_rating': '3.96',
#   'author_id': '1202800',
#   'text_reviews_count': '99',
#   'name': 'Jacob Appel',
#   'ratings_count': '820'},
#  {'average_rating': '3.69',
#   'author_id': '4492199',
#   'text_reviews_count': '182',
#   'name': 'Elena Cantoni',
#   'ratings_count': '1139'},
#  {'average_rating': '3.76',
#   'author_id': '2742909',
#   'text_reviews_count': '120',
#   'name': "'krm rD",
#   'ratings_count': '955'},
#  {'average_rating': '3.92',
#   'author_id': '8258',
#   'text_reviews_count': '4375',
#   'name': 'Martin Cruz Smith',
#   'ratings_count': '91438'},
#  {'average_rating': '4.38',
#   'author_id': '4391289',
#   'text_reviews_count': '213',
#   'name': 'Jeon Geuk-Jin',
#   'ratings_count': '9517'},
#  {'average_rating': '3.51',
#   'author_id': '6537142',
#   'text_reviews_count': '369',
#   'name': 'Rebecca Podos',
#   'ratings_count': '1493'},
#  {'average_rating': '4.34',
#   'author_id': '4973079',
#   'text_reviews_count': '34',
#   'name': 'Cali',
#   'ratings_count': '126'},
#  {'average_rating': '3.46',
#   'author_id': '3377500',
#   'text_reviews_count': '3',
#   'name': 'Andrea Tezumo',
#   'ratings_count': '13'},
#  {'average_rating': '4.01',
#   'author_id': '51646',
#   'text_reviews_count': '549',
#   'name': 'Joseph E. Persico',
#   'ratings_count': '7327'},
#  {'average_rating': '4.07',
#   'author_id': '2736959',
#   'text_reviews_count': '195',
#   'name': 'Cia Leah',
#   'ratings_count': '2978'},
#  {'average_rating': '3.12',
#   'author_id': '16996479',
#   'text_reviews_count': '7',
#   'name': 'N Gray',
#   'ratings_count': '8'},
#  {'average_rating': '3.36',
#   'author_id': '714123',
#   'text_reviews_count': '4',
#   'name': 'Mary Elsie Robertson',
#   'ratings_count': '22'},
#  {'average_rating': '4.00',
#   'author_id': '7265977',
#   'text_reviews_count': '242',
#   'name': 'Piers Platt',
#   'ratings_count': '2849'},
#  {'average_rating': '4.15',
#   'author_id': '6466154',
#   'text_reviews_count': '12491',
#   'name': 'Kahlil Gibran',
#   'ratings_count': '232111'},
#  {'average_rating': '4.06',
#   'author_id': '2978217',
#   'text_reviews_count': '16',
#   'name': 'jmyl jbr',
#   'ratings_count': '126'},
#  {'average_rating': '3.00',
#   'author_id': '5873266',
#   'text_reviews_count': '1',
#   'name': 'Ralph Peduto',
#   'ratings_count': '1'},
#  {'average_rating': '4.42',
#   'author_id': '3037628',
#   'text_reviews_count': '17',
#   'name': 'Gregory Gerard',
#   'ratings_count': '53'},
#  {'average_rating': '3.97',
#   'author_id': '4529674',
#   'text_reviews_count': '1283',
#   'name': 'Rue Volley',
#   'ratings_count': '5828'},
#  {'average_rating': '4.13',
#   'author_id': '370361',
#   'text_reviews_count': '64810',
#   'name': 'Patrick Ness',
#   'ratings_count': '454626'},
#  {'average_rating': '3.56',
#   'author_id': '2760047',
#   'text_reviews_count': '41',
#   'name': 'Merri Vik',
#   'ratings_count': '1369'},
#  {'average_rating': '3.46',
#   'author_id': '4589095',
#   'text_reviews_count': '9',
#   'name': 'A.-M. Helminen',
#   'ratings_count': '255'},
#  {'average_rating': '3.93',
#   'author_id': '11315',
#   'text_reviews_count': '8618',
#   'name': 'Evelyn Waugh',
#   'ratings_count': '158312'},
#  {'average_rating': '2.66',
#   'author_id': '7151691',
#   'text_reviews_count': '9',
#   'name': 'Justin Kairo',
#   'ratings_count': '97'},
#  {'average_rating': '3.89',
#   'author_id': '6761385',
#   'text_reviews_count': '92',
#   'name': 'Vipin Behari Goyal',
#   'ratings_count': '220'},
#  {'average_rating': '4.01',
#   'author_id': '71251',
#   'text_reviews_count': '36',
#   'name': 'Diane Davis White',
#   'ratings_count': '308'},
#  {'average_rating': '4.28',
#   'author_id': '182281',
#   'text_reviews_count': '8',
#   'name': 'Vincent VI Warren',
#   'ratings_count': '32'},
#  {'average_rating': '3.77',
#   'author_id': '445601',
#   'text_reviews_count': '75',
#   'name': 'Gail Feichtinger',
#   'ratings_count': '412'},
#  {'average_rating': '3.78',
#   'author_id': '209811',
#   'text_reviews_count': '71',
#   'name': 'Gary Waller',
#   'ratings_count': '398'},
#  {'average_rating': '3.78',
#   'author_id': '445600',
#   'text_reviews_count': '70',
#   'name': 'John DeSanto',
#   'ratings_count': '390'},
#  {'average_rating': '3.75',
#   'author_id': '4459027',
#   'text_reviews_count': '4',
#   'name': 'Michel Bonnefoy',
#   'ratings_count': '8'},
#  {'average_rating': '4.00',
#   'author_id': '4383146',
#   'text_reviews_count': '18',
#   'name': 'Dennis Milam Bensie',
#   'ratings_count': '51'},
#  {'average_rating': '3.53',
#   'author_id': '1521399',
#   'text_reviews_count': '3',
#   'name': 'Aaron Council',
#   'ratings_count': '32'},
#  {'average_rating': '3.35',
#   'author_id': '7992537',
#   'text_reviews_count': '3',
#   'name': 'Michael Petch',
#   'ratings_count': '26'},
#  {'average_rating': '3.46',
#   'author_id': '1241765',
#   'text_reviews_count': '3',
#   'name': 'Edward Long',
#   'ratings_count': '26'},
#  {'average_rating': '3.91',
#   'author_id': '12020074',
#   'text_reviews_count': '385',
#   'name': 'Kate Rudolph',
#   'ratings_count': '2146'},
#  {'average_rating': '3.72',
#   'author_id': '7323',
#   'text_reviews_count': '314',
#   'name': 'Charles Reasoner',
#   'ratings_count': '1516'},
#  {'average_rating': '3.84',
#   'author_id': '3039530',
#   'text_reviews_count': '98',
#   'name': 'Marina Le Ray',
#   'ratings_count': '371'},
#  {'average_rating': '3.47',
#   'author_id': '1102395',
#   'text_reviews_count': '3174',
#   'name': 'Meg Waite Clayton',
#   'ratings_count': '16912'},
#  {'average_rating': '3.43',
#   'author_id': '2776840',
#   'text_reviews_count': '48',
#   'name': 'Abdullah Harahap',
#   'ratings_count': '161'},
#  {'average_rating': '4.06',
#   'author_id': '8164',
#   'text_reviews_count': '24057',
#   'name': 'Lewis Carroll',
#   'ratings_count': '1022402'},
#  {'average_rating': '3.91',
#   'author_id': '777644',
#   'text_reviews_count': '36',
#   'name': 'Roberto Gervaso',
#   'ratings_count': '546'},
#  {'average_rating': '4.04',
#   'author_id': '36346',
#   'text_reviews_count': '17170',
#   'name': 'Jennifer Donnelly',
#   'ratings_count': '143792'},
#  {'average_rating': '4.10',
#   'author_id': '5137697',
#   'text_reviews_count': '203',
#   'name': 'Cathryn Hein',
#   'ratings_count': '1141'},
#  {'average_rating': '3.97',
#   'author_id': '13501628',
#   'text_reviews_count': '62',
#   'name': 'A.J. Coonley',
#   'ratings_count': '95'},
#  {'average_rating': '3.79',
#   'author_id': '19697',
#   'text_reviews_count': '8444',
#   'name': 'Robin Cook',
#   'ratings_count': '257355'},
#  {'average_rating': '2.47',
#   'author_id': '7872218',
#   'text_reviews_count': '7',
#   'name': 'J.P. Cuenca',
#   'ratings_count': '19'},
#  {'average_rating': '4.13',
#   'author_id': '88746',
#   'text_reviews_count': '51',
#   'name': 'Elizabeth Lowe',
#   'ratings_count': '621'},
#  {'average_rating': '3.95',
#   'author_id': '7792315',
#   'text_reviews_count': '190',
#   'name': 'Leila Lacey',
#   'ratings_count': '1044'},
#  {'average_rating': '3.90',
#   'author_id': '172490',
#   'text_reviews_count': '5213',
#   'name': 'Jim C. Hines',
#   'ratings_count': '42461'},
#  {'average_rating': '3.80',
#   'author_id': '2490272',
#   'text_reviews_count': '285',
#   'name': 'Carol Monda',
#   'ratings_count': '1203'},
#  {'average_rating': '3.92',
#   'author_id': '48516',
#   'text_reviews_count': '741',
#   'name': 'David Handler',
#   'ratings_count': '6854'},
#  {'average_rating': '3.95',
#   'author_id': '15441',
#   'text_reviews_count': '3513',
#   'name': 'Bob Woodward',
#   'ratings_count': '73037'},
#  {'average_rating': '3.20',
#   'author_id': '7872217',
#   'text_reviews_count': '3',
#   'name': 'bwb wwdwrd',
#   'ratings_count': '5'},
#  {'average_rating': '3.88',
#   'author_id': '12935',
#   'text_reviews_count': '1045',
#   'name': 'Shannon Drake',
#   'ratings_count': '17573'},
#  {'average_rating': '4.66',
#   'author_id': '7362076',
#   'text_reviews_count': '18',
#   'name': 'Claire  Smith',
#   'ratings_count': '32'},
#  {'average_rating': '4.01',
#   'author_id': '17854',
#   'text_reviews_count': '4357',
#   'name': 'Bertrand Russell',
#   'ratings_count': '91674'},
#  {'average_rating': '4.15',
#   'author_id': '3112114',
#   'text_reviews_count': '448',
#   'name': 'Alexey Pehov',
#   'ratings_count': '11019'},
#  {'average_rating': '4.07',
#   'author_id': '667143',
#   'text_reviews_count': '219',
#   'name': 'Christiane Pohlmann',
#   'ratings_count': '6461'},
#  {'average_rating': '3.62',
#   'author_id': '3029755',
#   'text_reviews_count': '60',
#   'name': 'Oren Harman',
#   'ratings_count': '421'},
#  {'average_rating': '4.54',
#   'author_id': '15203920',
#   'text_reviews_count': '162',
#   'name': 'Blair Merrin',
#   'ratings_count': '559'},
#  {'average_rating': '3.99',
#   'author_id': '25108',
#   'text_reviews_count': '2920',
#   'name': 'P.J. Tracy',
#   'ratings_count': '30991'},
#  {'average_rating': '3.92',
#   'author_id': '2339869',
#   'text_reviews_count': '291',
#   'name': 'Buck Schirner',
#   'ratings_count': '1789'},
#  {'average_rating': '3.79',
#   'author_id': '7414637',
#   'text_reviews_count': '46',
#   'name': 'Kazumasa Hirai',
#   'ratings_count': '1450'},
#  {'average_rating': '4.17',
#   'author_id': '18540',
#   'text_reviews_count': '5892',
#   'name': 'T.S. Eliot',
#   'ratings_count': '189956'},
#  {'average_rating': '4.20',
#   'author_id': '248155',
#   'text_reviews_count': '73',
#   'name': 'Errol Le Cain',
#   'ratings_count': '570'},
#  {'average_rating': '3.53',
#   'author_id': '5344544',
#   'text_reviews_count': '5',
#   'name': 'Pablo Rumel',
#   'ratings_count': '34'},
#  {'average_rating': '3.70',
#   'author_id': '32119',
#   'text_reviews_count': '105',
#   'name': 'Richard Wilson',
#   'ratings_count': '1142'},
#  {'average_rating': '3.92',
#   'author_id': '23113',
#   'text_reviews_count': '2468',
#   'name': 'John Brunner',
#   'ratings_count': '50219'},
#  {'average_rating': '3.30',
#   'author_id': '6979307',
#   'text_reviews_count': '13',
#   'name': 'D.M.J. Aurini',
#   'ratings_count': '63'},
#  {'average_rating': '4.12',
#   'author_id': '6553943',
#   'text_reviews_count': '5',
#   'name': 'Venice Kennedy',
#   'ratings_count': '16'},
#  {'average_rating': '4.17',
#   'author_id': '3137322',
#   'text_reviews_count': '42613',
#   'name': 'Fyodor Dostoyevsky',
#   'ratings_count': '1052406'},
#  {'average_rating': '4.10',
#   'author_id': '69892',
#   'text_reviews_count': '8280',
#   'name': 'Constance Garnett',
#   'ratings_count': '170554'},
#  {'average_rating': '3.44',
#   'author_id': '5576046',
#   'text_reviews_count': '11',
#   'name': 'Moussa Konate',
#   'ratings_count': '72'},
#  {'average_rating': '3.15',
#   'author_id': '4669632',
#   'text_reviews_count': '6',
#   'name': 'Ondina Granato',
#   'ratings_count': '13'},
#  {'average_rating': '3.48',
#   'author_id': '7204031',
#   'text_reviews_count': '33',
#   'name': 'Ji Qiu',
#   'ratings_count': '181'},
#  {'average_rating': '3.48',
#   'author_id': '5622158',
#   'text_reviews_count': '33',
#   'name': 'cchiichiw',
#   'ratings_count': '181'},
#  {'average_rating': '3.97',
#   'author_id': '4037407',
#   'text_reviews_count': '326',
#   'name': 'phrikh`m',
#   'ratings_count': '2539'},
#  {'average_rating': '3.41',
#   'author_id': '523138',
#   'text_reviews_count': '259',
#   'name': 'Janet Ruth Young',
#   'ratings_count': '1153'},
#  {'average_rating': '4.07',
#   'author_id': '3420',
#   'text_reviews_count': '1716',
#   'name': 'Elizabeth Enright',
#   'ratings_count': '30738'},
#  {'average_rating': '4.26',
#   'author_id': '1045743',
#   'text_reviews_count': '116',
#   'name': 'Iain McGilchrist',
#   'ratings_count': '999'},
#  {'average_rating': '3.77',
#   'author_id': '26899',
#   'text_reviews_count': '1510',
#   'name': 'Edward Marston',
#   'ratings_count': '13366'},
#  {'average_rating': '3.68',
#   'author_id': '13730',
#   'text_reviews_count': '30300',
#   'name': 'R.L. Stine',
#   'ratings_count': '670491'},
#  {'average_rating': '3.51',
#   'author_id': '570512',
#   'text_reviews_count': '28',
#   'name': 'Desmond Barry',
#   'ratings_count': '202'},
#  {'average_rating': '3.84',
#   'author_id': '854076',
#   'text_reviews_count': '24362',
#   'name': 'Robert Louis Stevenson',
#   'ratings_count': '834908'},
#  {'average_rating': '3.93',
#   'author_id': '539783',
#   'text_reviews_count': '18',
#   'name': 'Debra Coleman Jeter',
#   'ratings_count': '81'},
#  {'average_rating': '4.03',
#   'author_id': '11058226',
#   'text_reviews_count': '293',
#   'name': 'Cassie-Ann L. Miller',
#   'ratings_count': '1752'},
#  {'average_rating': '3.82',
#   'author_id': '263567',
#   'text_reviews_count': '3227',
#   'name': 'Marie Harte',
#   'ratings_count': '38801'},
#  {'average_rating': '2.86',
#   'author_id': '474995',
#   'text_reviews_count': '1',
#   'name': 'Frank Cain',
#   'ratings_count': '7'},
#  {'average_rating': '3.22',
#   'author_id': '6179571',
#   'text_reviews_count': '3',
#   'name': 'Jp Jones',
#   'ratings_count': '9'},
#  {'average_rating': '3.95',
#   'author_id': '3354',
#   'text_reviews_count': '114375',
#   'name': 'Haruki Murakami',
#   'ratings_count': '1588319'},
#  {'average_rating': '3.51',
#   'author_id': '2943855',
#   'text_reviews_count': '634',
#   'name': 'Kat Menschik',
#   'ratings_count': '4599'},
#  {'average_rating': '3.80',
#   'author_id': '3217205',
#   'text_reviews_count': '493',
#   'name': 'Jacques Westerhoven',
#   'ratings_count': '5006'},
#  {'average_rating': '3.14',
#   'author_id': '15165816',
#   'text_reviews_count': '16',
#   'name': 'Riley Forrest',
#   'ratings_count': '59'},
#  {'average_rating': '3.16',
#   'author_id': '4741032',
#   'text_reviews_count': '8',
#   'name': 'P.L. Roberts',
#   'ratings_count': '43'},
#  {'average_rating': '2.97',
#   'author_id': '15265828',
#   'text_reviews_count': '6',
#   'name': 'Rachel Menage',
#   'ratings_count': '33'},
#  {'average_rating': '3.76',
#   'author_id': '386083',
#   'text_reviews_count': '70',
#   'name': 'Dover Publications Inc.',
#   'ratings_count': '1980'},
#  {'average_rating': '3.50',
#   'author_id': '5649650',
#   'text_reviews_count': '1',
#   'name': 'Victor Raysman',
#   'ratings_count': '2'},
#  {'average_rating': '4.25',
#   'author_id': '38569',
#   'text_reviews_count': '8638',
#   'name': 'Andrzej Sapkowski',
#   'ratings_count': '229661'},
#  {'average_rating': '3.73',
#   'author_id': '3255974',
#   'text_reviews_count': '250',
#   'name': 'Douglas  Smith',
#   'ratings_count': '1655'},
#  {'average_rating': '3.88',
#   'author_id': '10848928',
#   'text_reviews_count': '615',
#   'name': 'Kelley Harvey',
#   'ratings_count': '3187'},
#  {'average_rating': '3.91',
#   'author_id': '2784066',
#   'text_reviews_count': '194',
#   'name': 'mHmwd `wD',
#   'ratings_count': '1230'},
#  {'average_rating': '4.05',
#   'author_id': '639570',
#   'text_reviews_count': '145',
#   'name': 'Jean-Francois Revel',
#   'ratings_count': '1564'},
#  {'average_rating': '3.97',
#   'author_id': '3194718',
#   'text_reviews_count': '26',
#   'name': 'Diarmid Cammell',
#   'ratings_count': '172'},
#  {'average_rating': '3.86',
#   'author_id': '18791',
#   'text_reviews_count': '4662',
#   'name': 'Guy de Maupassant',
#   'ratings_count': '90449'},
#  {'average_rating': '3.40',
#   'author_id': '415236',
#   'text_reviews_count': '3',
#   'name': 'Kirsty White',
#   'ratings_count': '30'},
#  {'average_rating': '4.10',
#   'author_id': '12855',
#   'text_reviews_count': '5315',
#   'name': 'Neil deGrasse Tyson',
#   'ratings_count': '56667'},
#  {'average_rating': '3.93',
#   'author_id': '17045',
#   'text_reviews_count': '302',
#   'name': 'Wendy Cheyette Lewison',
#   'ratings_count': '1808'},
#  {'average_rating': '4.00',
#   'author_id': '7059622',
#   'text_reviews_count': '7598',
#   'name': 'Ilsa Madden-Mills',
#   'ratings_count': '62243'},
#  {'average_rating': '3.89',
#   'author_id': '7516813',
#   'text_reviews_count': '903',
#   'name': 'Amber A. Bardan',
#   'ratings_count': '3115'},
#  {'average_rating': '3.92',
#   'author_id': '4750',
#   'text_reviews_count': '5537',
#   'name': 'Emile Zola',
#   'ratings_count': '102884'},
#  {'average_rating': '3.96',
#   'author_id': '31107',
#   'text_reviews_count': '420',
#   'name': 'Diana Preston',
#   'ratings_count': '3239'},
#  {'average_rating': '3.75',
#   'author_id': '127562',
#   'text_reviews_count': '862',
#   'name': 'Kader Abdolah',
#   'ratings_count': '10639'},
#  {'average_rating': '3.75',
#   'author_id': '243000',
#   'text_reviews_count': '21',
#   'name': 'Jerry MacGregor',
#   'ratings_count': '106'},
#  {'average_rating': '4.13',
#   'author_id': '24945',
#   'text_reviews_count': '147',
#   'name': 'Keri Wyatt Kent',
#   'ratings_count': '559'},
#  {'average_rating': '3.82',
#   'author_id': '10885',
#   'text_reviews_count': '11255',
#   'name': 'Edgar Rice Burroughs',
#   'ratings_count': '220737'},
#  {'average_rating': '3.81',
#   'author_id': '169992',
#   'text_reviews_count': '1482',
#   'name': 'JoAnna Carl',
#   'ratings_count': '18686'},
#  {'average_rating': '4.13',
#   'author_id': '777491',
#   'text_reviews_count': '18',
#   'name': 'Helen Henderson',
#   'ratings_count': '62'},
#  {'average_rating': '3.47',
#   'author_id': '5358028',
#   'text_reviews_count': '3',
#   'name': 'nbyl lwq bbwy',
#   'ratings_count': '19'},
#  {'average_rating': '3.00',
#   'author_id': '8929891',
#   'text_reviews_count': '1',
#   'name': 'R.T. Stroud',
#   'ratings_count': '1'},
#  {'average_rating': '4.04',
#   'author_id': '104544',
#   'text_reviews_count': '704',
#   'name': 'Meir Shalev',
#   'ratings_count': '6436'},
#  {'average_rating': '4.27',
#   'author_id': '7151511',
#   'text_reviews_count': '29',
#   'name': 'Oto Havrila',
#   'ratings_count': '142'},
#  {'average_rating': '4.09',
#   'author_id': '12504',
#   'text_reviews_count': '34838',
#   'name': 'Karin Slaughter',
#   'ratings_count': '519631'},
#  {'average_rating': '4.21',
#   'author_id': '26957',
#   'text_reviews_count': '3453',
#   'name': 'Gerald Durrell',
#   'ratings_count': '57133'},
#  {'average_rating': '3.95',
#   'author_id': '3238619',
#   'text_reviews_count': '6426',
#   'name': 'Julia Kent',
#   'ratings_count': '65089'},
#  {'average_rating': '3.78',
#   'author_id': '2926031',
#   'text_reviews_count': '885',
#   'name': 'Tanya Eby',
#   'ratings_count': '3979'},
#  {'average_rating': '4.19',
#   'author_id': '238787',
#   'text_reviews_count': '191',
#   'name': 'Philip Van Doren Stern',
#   'ratings_count': '1972'},
#  {'average_rating': '4.12',
#   'author_id': '4697205',
#   'text_reviews_count': '3',
#   'name': 'James Dunwoody Bulloch',
#   'ratings_count': '8'},
#  {'average_rating': '4.10',
#   'author_id': '70026',
#   'text_reviews_count': '16774',
#   'name': 'Scott Snyder',
#   'ratings_count': '249636'},
#  {'average_rating': '3.82',
#   'author_id': '5752063',
#   'text_reviews_count': '299',
#   'name': 'Scott Tuft',
#   'ratings_count': '3616'},
#  {'average_rating': '4.01',
#   'author_id': '3376756',
#   'text_reviews_count': '1810',
#   'name': 'Attila Futaki',
#   'ratings_count': '25476'},
#  {'average_rating': '4.18',
#   'author_id': '8583486',
#   'text_reviews_count': '21',
#   'name': 'Greg Guilhaumond',
#   'ratings_count': '334'},
#  {'average_rating': '4.90',
#   'author_id': '14308759',
#   'text_reviews_count': '8',
#   'name': 'Nicole Rollender',
#   'ratings_count': '21'},
#  {'average_rating': '3.69',
#   'author_id': '2952441',
#   'text_reviews_count': '652',
#   'name': 'Chris Quinton',
#   'ratings_count': '2478'},
#  {'average_rating': '4.37',
#   'author_id': '608923',
#   'text_reviews_count': '12',
#   'name': 'Andrzej Bobkowski',
#   'ratings_count': '155'},
#  {'average_rating': '4.21',
#   'author_id': '669810',
#   'text_reviews_count': '39561',
#   'name': 'Jeaniene Frost',
#   'ratings_count': '737170'},
#  {'average_rating': '4.53',
#   'author_id': '411899',
#   'text_reviews_count': '543',
#   'name': 'Thomas S. Monson',
#   'ratings_count': '3826'},
#  {'average_rating': '5.00',
#   'author_id': '5815821',
#   'text_reviews_count': '2',
#   'name': 'Todd Warren',
#   'ratings_count': '3'},
#  {'average_rating': '5.00',
#   'author_id': '5815822',
#   'text_reviews_count': '2',
#   'name': 'Dale Cameron',
#   'ratings_count': '3'},
#  {'average_rating': '4.16',
#   'author_id': '6948888',
#   'text_reviews_count': '134',
#   'name': 'Laura J. Marshall',
#   'ratings_count': '728'},
#  {'average_rating': '3.72',
#   'author_id': '214232',
#   'text_reviews_count': '1566',
#   'name': 'David Anthony Durham',
#   'ratings_count': '19736'},
#  {'average_rating': '3.85',
#   'author_id': '441879',
#   'text_reviews_count': '17',
#   'name': 'Montserrat Gurgui',
#   'ratings_count': '149'},
#  {'average_rating': '3.96',
#   'author_id': '13757',
#   'text_reviews_count': '12557',
#   'name': 'Lisa Jackson',
#   'ratings_count': '204851'},
#  {'average_rating': '3.82',
#   'author_id': '25707',
#   'text_reviews_count': '99',
#   'name': 'Francisco Umbral',
#   'ratings_count': '1172'},
#  {'average_rating': '4.06',
#   'author_id': '8328712',
#   'text_reviews_count': '1027',
#   'name': 'Laura  Ward',
#   'ratings_count': '5800'},
#  {'average_rating': '4.17',
#   'author_id': '7218946',
#   'text_reviews_count': '549',
#   'name': 'Christine Manzari',
#   'ratings_count': '1747'},
#  {'average_rating': '3.96',
#   'author_id': '15613826',
#   'text_reviews_count': '302',
#   'name': 'Iris Morland',
#   'ratings_count': '1178'},
#  {'average_rating': '4.17',
#   'author_id': '44415',
#   'text_reviews_count': '645',
#   'name': 'Tom Spanbauer',
#   'ratings_count': '4615'},
#  {'average_rating': '3.54',
#   'author_id': '26086',
#   'text_reviews_count': '32',
#   'name': 'Juan Antonio Cebrian',
#   'ratings_count': '532'},
#  {'average_rating': '3.39',
#   'author_id': '5815823',
#   'text_reviews_count': '7',
#   'name': 'MobiPoki',
#   'ratings_count': '220'},
#  {'average_rating': '3.94',
#   'author_id': '33200',
#   'text_reviews_count': '444',
#   'name': 'Henri Troyat',
#   'ratings_count': '6880'},
#  {'average_rating': '3.88',
#   'author_id': '2785768',
#   'text_reviews_count': '8',
#   'name': 'Rajiv Dogra',
#   'ratings_count': '84'},
#  {'average_rating': '2.97',
#   'author_id': '12599442',
#   'text_reviews_count': '6',
#   'name': 'Ashlee Beaunoir',
#   'ratings_count': '30'},
#  {'average_rating': '3.94',
#   'author_id': '596418',
#   'text_reviews_count': '175',
#   'name': 'Andy Cutbill',
#   'ratings_count': '1259'},
#  {'average_rating': '3.90',
#   'author_id': '165280',
#   'text_reviews_count': '643',
#   'name': 'Russell Ayto',
#   'ratings_count': '3849'},
#  {'average_rating': '3.87',
#   'author_id': '5834730',
#   'text_reviews_count': '362',
#   'name': 'Irene Preston',
#   'ratings_count': '1070'},
#  {'average_rating': '4.00',
#   'author_id': '5609664',
#   'text_reviews_count': '432',
#   'name': 'Liv Rancourt',
#   'ratings_count': '1214'},
#  {'average_rating': '3.67',
#   'author_id': '4996195',
#   'text_reviews_count': '2',
# ...
#   'text_reviews_count': '10',
#   'name': 'Eric Cherry',
#   'ratings_count': '113'},
#  {'average_rating': '3.33',
#   'author_id': '5347217',
#   'text_reviews_count': '1',
#   'name': 'Jennifer Bach',
#   'ratings_count': '6'},
#  {'average_rating': '3.33',
#   'author_id': '5347218',
#   'text_reviews_count': '1',
#   'name': 'Amy Brost',
#   'ratings_count': '6'},
#  {'average_rating': '3.72',
#   'author_id': '42275',
#   'text_reviews_count': '100',
#   'name': 'Judith Mitchell',
#   'ratings_count': '2432'},
#  {'average_rating': '3.69',
#   'author_id': '52432',
#   'text_reviews_count': '79',
#   'name': 'Stanley G. Payne',
#   'ratings_count': '545'},
#  {'average_rating': '4.80',
#   'author_id': '15024396',
#   'text_reviews_count': '9',
#   'name': 'Toni Cox',
#   'ratings_count': '25'},
#  {'average_rating': '4.00',
#   'author_id': '7214107',
#   'text_reviews_count': '21',
#   'name': 'Tessy Rawlins',
#   'ratings_count': '354'},
#  {'average_rating': '4.21',
#   'author_id': '4524500',
#   'text_reviews_count': '21',
#   'name': 'Celso Cukierkorn',
#   'ratings_count': '164'},
#  {'average_rating': '4.05',
#   'author_id': '1244',
#   'text_reviews_count': '73268',
#   'name': 'Mark Twain',
#   'ratings_count': '4087862'},
#  {'average_rating': '2.86',
#   'author_id': '2779162',
#   'text_reviews_count': '22',
#   'name': 'Martijn J. Adelmund',
#   'ratings_count': '103'},
#  {'average_rating': '3.97',
#   'author_id': '7133378',
#   'text_reviews_count': '2140',
#   'name': 'Alexis Noelle',
#   'ratings_count': '8567'},
#  {'average_rating': '3.77',
#   'author_id': '254202',
#   'text_reviews_count': '21',
#   'name': 'Roger Alan Skipper',
#   'ratings_count': '87'},
#  {'average_rating': '3.53',
#   'author_id': '5831332',
#   'text_reviews_count': '19',
#   'name': 'Oystein Runde',
#   'ratings_count': '129'},
#  {'average_rating': '3.70',
#   'author_id': '7519603',
#   'text_reviews_count': '2',
#   'name': 'Ida Neverdahl',
#   'ratings_count': '20'},
#  {'average_rating': '3.84',
#   'author_id': '6579126',
#   'text_reviews_count': '1687',
#   'name': 'Pip Ballantine',
#   'ratings_count': '13865'},
#  {'average_rating': '3.87',
#   'author_id': '460870',
#   'text_reviews_count': '1817',
#   'name': 'Tee Morris',
#   'ratings_count': '15859'},
#  {'average_rating': '3.56',
#   'author_id': '5206280',
#   'text_reviews_count': '11',
#   'name': 'Frode Eie Larsen',
#   'ratings_count': '64'},
#  {'average_rating': '3.81',
#   'author_id': '1856577',
#   'text_reviews_count': '48',
#   'name': 'Anna Brzezinska',
#   'ratings_count': '1413'},
#  {'average_rating': '4.27',
#   'author_id': '404567',
#   'text_reviews_count': '140',
#   'name': 'Rice Broocks',
#   'ratings_count': '1394'},
#  {'average_rating': '4.56',
#   'author_id': '2864316',
#   'text_reviews_count': '197',
#   'name': 'Laura Story',
#   'ratings_count': '1132'},
#  {'average_rating': '4.03',
#   'author_id': '8145659',
#   'text_reviews_count': '72',
#   'name': 'Dale Partridge',
#   'ratings_count': '648'},
#  {'average_rating': '4.05',
#   'author_id': '3261733',
#   'text_reviews_count': '821',
#   'name': 'Blake Mycoskie',
#   'ratings_count': '7786'},
#  {'average_rating': '4.02',
#   'author_id': '4043',
#   'text_reviews_count': '7107',
#   'name': 'Wilbur Smith',
#   'ratings_count': '191498'},
#  {'average_rating': '2.33',
#   'author_id': '8559303',
#   'text_reviews_count': '1',
#   'name': 'syrws khwpl',
#   'ratings_count': '3'},
#  {'average_rating': '3.55',
#   'author_id': '801962',
#   'text_reviews_count': '74',
#   'name': 'Melissa Wyatt',
#   'ratings_count': '368'},
#  {'average_rating': '3.46',
#   'author_id': '4518555',
#   'text_reviews_count': '9',
#   'name': 'Harvard Health Publications',
#   'ratings_count': '71'},
#  {'average_rating': '3.78',
#   'author_id': '150037',
#   'text_reviews_count': '678',
#   'name': 'Ward Just',
#   'ratings_count': '5885'},
#  {'average_rating': '3.92',
#   'author_id': '4052252',
#   'text_reviews_count': '1327',
#   'name': 'Marissa Farrar',
#   'ratings_count': '6835'},
#  {'average_rating': '4.23',
#   'author_id': '7417657',
#   'text_reviews_count': '832',
#   'name': "Cook's Illustrated Magazine",
#   'ratings_count': '31181'},
#  {'average_rating': '4.01',
#   'author_id': '45429',
#   'text_reviews_count': '6916',
#   'name': 'Jeffrey Brown',
#   'ratings_count': '69611'},
#  {'average_rating': '3.76',
#   'author_id': '72043',
#   'text_reviews_count': '467',
#   'name': 'John D. Barrow',
#   'ratings_count': '5475'},
#  {'average_rating': '3.52',
#   'author_id': '61625',
#   'text_reviews_count': '91',
#   'name': 'Frank J. Tipler',
#   'ratings_count': '683'},
#  {'average_rating': '3.67',
#   'author_id': '1461',
#   'text_reviews_count': '9706',
#   'name': 'Gustave Flaubert',
#   'ratings_count': '226017'},
#  {'average_rating': '3.56',
#   'author_id': '127738',
#   'text_reviews_count': '67',
#   'name': 'Alexis Stamatis',
#   'ratings_count': '953'},
#  {'average_rating': '3.73',
#   'author_id': '202258',
#   'text_reviews_count': '38',
#   'name': 'David Connolly',
#   'ratings_count': '317'},
#  {'average_rating': '3.76',
#   'author_id': '2047242',
#   'text_reviews_count': '4048',
#   'name': 'Stephani Hecht',
#   'ratings_count': '58909'},
#  {'average_rating': '4.00',
#   'author_id': '61099',
#   'text_reviews_count': '590',
#   'name': 'Paul Greenberg',
#   'ratings_count': '5056'},
#  {'average_rating': '3.72',
#   'author_id': '114626',
#   'text_reviews_count': '526',
#   'name': 'Christopher Lane',
#   'ratings_count': '2769'},
#  {'average_rating': '3.68',
#   'author_id': '161054',
#   'text_reviews_count': '3153',
#   'name': 'Hakan Nesser',
#   'ratings_count': '41155'},
#  {'average_rating': '3.96',
#   'author_id': '6458644',
#   'text_reviews_count': '159',
#   'name': "Eva K'neva",
#   'ratings_count': '1202'},
#  {'average_rating': '3.95',
#   'author_id': '13260036',
#   'text_reviews_count': '16',
#   'name': 'Salil Jha',
#   'ratings_count': '40'},
#  {'average_rating': '3.78',
#   'author_id': '137386',
#   'text_reviews_count': '3464',
#   'name': 'Vicki Pettersson',
#   'ratings_count': '52887'},
#  {'average_rating': '3.65',
#   'author_id': '58013',
#   'text_reviews_count': '1023',
#   'name': 'Johanna Sinisalo',
#   'ratings_count': '8289'},
#  {'average_rating': '3.55',
#   'author_id': '623602',
#   'text_reviews_count': '378',
#   'name': 'Herbert Lomas',
#   'ratings_count': '2501'},
#  {'average_rating': '3.74',
#   'author_id': '1880316',
#   'text_reviews_count': '567',
#   'name': 'Sharon Ashwood',
#   'ratings_count': '5646'},
#  {'average_rating': '3.85',
#   'author_id': '44540',
#   'text_reviews_count': '1578',
#   'name': 'Jan Burke',
#   'ratings_count': '19492'},
#  {'average_rating': '4.23',
#   'author_id': '46782',
#   'text_reviews_count': '22',
#   'name': 'Juliette Morillot',
#   'ratings_count': '228'},
#  {'average_rating': '4.24',
#   'author_id': '5822041',
#   'text_reviews_count': '3121',
#   'name': 'Eduardo Galeano',
#   'ratings_count': '30778'},
#  {'average_rating': '3.52',
#   'author_id': '7379968',
#   'text_reviews_count': '183',
#   'name': 'M.P. Cooley',
#   'ratings_count': '844'},
#  {'average_rating': '3.95',
#   'author_id': '5784640',
#   'text_reviews_count': '263',
#   'name': 'Marlayna Glynn',
#   'ratings_count': '2081'},
#  {'average_rating': '3.90',
#   'author_id': '673768',
#   'text_reviews_count': '7',
#   'name': 'Homer W. Sykes',
#   'ratings_count': '40'},
#  {'average_rating': '3.91',
#   'author_id': '721481',
#   'text_reviews_count': '821',
#   'name': 'Elisabeth Waters',
#   'ratings_count': '30534'},
#  {'average_rating': '3.47',
#   'author_id': '980713',
#   'text_reviews_count': '486',
#   'name': 'Annie Burrows',
#   'ratings_count': '3268'},
#  {'average_rating': '3.75',
#   'author_id': '8293670',
#   'text_reviews_count': '5',
#   'name': 'Sekji Ani',
#   'ratings_count': '12'},
#  {'average_rating': '3.59',
#   'author_id': '4829338',
#   'text_reviews_count': '2296',
#   'name': 'Charles River Editors',
#   'ratings_count': '22367'},
#  {'average_rating': '3.67',
#   'author_id': '14106216',
#   'text_reviews_count': '480',
#   'name': 'Selina Coffey',
#   'ratings_count': '1704'},
#  {'average_rating': '3.61',
#   'author_id': '174946',
#   'text_reviews_count': '276',
#   'name': 'Jack Goldstein',
#   'ratings_count': '6209'},
#  {'average_rating': '3.90',
#   'author_id': '6206',
#   'text_reviews_count': '5202',
#   'name': 'Jenny Nimmo',
#   'ratings_count': '165124'},
#  {'average_rating': '3.94',
#   'author_id': '7722',
#   'text_reviews_count': '729',
#   'name': 'Louise Borden',
#   'ratings_count': '3279'},
#  {'average_rating': '3.91',
#   'author_id': '289245',
#   'text_reviews_count': '869',
#   'name': 'Robert Andrew Parker',
#   'ratings_count': '14163'},
#  {'average_rating': '4.06',
#   'author_id': '7195',
#   'text_reviews_count': '28600',
#   'name': 'John Boyne',
#   'ratings_count': '437743'},
#  {'average_rating': '3.86',
#   'author_id': '5862584',
#   'text_reviews_count': '91',
#   'name': 'Ivan Repila',
#   'ratings_count': '396'},
#  {'average_rating': '4.04',
#   'author_id': '6259',
#   'text_reviews_count': '6083',
#   'name': 'Kay Hooper',
#   'ratings_count': '155831'},
#  {'average_rating': '4.00',
#   'author_id': '73435',
#   'text_reviews_count': '41',
#   'name': 'Maxine Chernoff',
#   'ratings_count': '315'},
#  {'average_rating': '4.04',
#   'author_id': '13490770',
#   'text_reviews_count': '632',
#   'name': 'Ivy Smoak',
#   'ratings_count': '4445'},
#  {'average_rating': '3.91',
#   'author_id': '5080042',
#   'text_reviews_count': '1108',
#   'name': 'Brandon Shire',
#   'ratings_count': '4457'},
#  {'average_rating': '4.12',
#   'author_id': '6693826',
#   'text_reviews_count': '106',
#   'name': 'Seth Andrews',
#   'ratings_count': '949'},
#  {'average_rating': '3.51',
#   'author_id': '5820186',
#   'text_reviews_count': '41',
#   'name': 'Brandon R. Luffman',
#   'ratings_count': '131'},
#  {'average_rating': '4.01',
#   'author_id': '373526',
#   'text_reviews_count': '11',
#   'name': 'Elisa Springer',
#   'ratings_count': '115'},
#  {'average_rating': '4.03',
#   'author_id': '5827833',
#   'text_reviews_count': '367',
#   'name': 'Kristina Knight',
#   'ratings_count': '1588'},
#  {'average_rating': '3.62',
#   'author_id': '2864598',
#   'text_reviews_count': '188',
#   'name': 'Debra Glass',
#   'ratings_count': '1719'},
#  {'average_rating': '3.23',
#   'author_id': '1245772',
#   'text_reviews_count': '17987',
#   'name': 'Herman Koch',
#   'ratings_count': '130391'},
#  {'average_rating': '3.31',
#   'author_id': '8523581',
#   'text_reviews_count': '3',
#   'name': 'Kees Hulst',
#   'ratings_count': '13'},
#  {'average_rating': '4.05',
#   'author_id': '347654',
#   'text_reviews_count': '149',
#   'name': 'Adian Husaini',
#   'ratings_count': '935'},
#  {'average_rating': '3.80',
#   'author_id': '5194',
#   'text_reviews_count': '45701',
#   'name': 'Michael Crichton',
#   'ratings_count': '1999836'},
#  {'average_rating': '3.97',
#   'author_id': '40573',
#   'text_reviews_count': '1204',
#   'name': 'Frank  Muller',
#   'ratings_count': '9000'},
#  {'average_rating': '4.24',
#   'author_id': '8106692',
#   'text_reviews_count': '311',
#   'name': 'Adam Dreece',
#   'ratings_count': '624'},
#  {'average_rating': '3.83',
#   'author_id': '118424',
#   'text_reviews_count': '10',
#   'name': 'Paul Kendall',
#   'ratings_count': '82'},
#  {'average_rating': '3.90',
#   'author_id': '7085769',
#   'text_reviews_count': '20',
#   'name': 'Brie McGill',
#   'ratings_count': '48'},
#  {'average_rating': '3.91',
#   'author_id': '6429866',
#   'text_reviews_count': '197',
#   'name': 'Brandy Nacole',
#   'ratings_count': '336'},
#  {'average_rating': '3.83',
#   'author_id': '4191',
#   'text_reviews_count': '27743',
#   'name': 'Emily Bronte',
#   'ratings_count': '1046247'},
#  {'average_rating': '3.99',
#   'author_id': '3114377',
#   'text_reviews_count': '19',
#   'name': 'Emili Bronte',
#   'ratings_count': '430'},
#  {'average_rating': '4.18',
#   'author_id': '865',
#   'text_reviews_count': '4888',
#   'name': 'Robert Greene',
#   'ratings_count': '83254'},
#  {'average_rating': '4.18',
#   'author_id': '12331',
#   'text_reviews_count': '3122',
#   'name': 'Joost Elffers',
#   'ratings_count': '53352'},
#  {'average_rating': '4.12',
#   'author_id': '4882127',
#   'text_reviews_count': '27757',
#   'name': 'Rachel Van Dyken',
#   'ratings_count': '269026'},
#  {'average_rating': '3.76',
#   'author_id': '7302191',
#   'text_reviews_count': '29',
#   'name': 'Shea Norwood',
#   'ratings_count': '58'},
#  {'average_rating': '4.03',
#   'author_id': '1441',
#   'text_reviews_count': '21402',
#   'name': 'Ted Dekker',
#   'ratings_count': '360209'},
#  {'average_rating': '3.75',
#   'author_id': '4028753',
#   'text_reviews_count': '55',
#   'name': 'Jan Steemers',
#   'ratings_count': '366'},
#  {'average_rating': '4.00',
#   'author_id': '22543',
#   'text_reviews_count': '1276',
#   'name': 'Meredith Ann Pierce',
#   'ratings_count': '25210'},
#  {'average_rating': '4.71',
#   'author_id': '5139621',
#   'text_reviews_count': '16',
#   'name': 'Dave  Moore',
#   'ratings_count': '31'},
#  {'average_rating': '3.42',
#   'author_id': '565621',
#   'text_reviews_count': '36',
#   'name': 'John A. Andrews',
#   'ratings_count': '245'},
#  {'average_rating': '3.80',
#   'author_id': '870',
#   'text_reviews_count': '1304',
#   'name': 'Holly Lisle',
#   'ratings_count': '22830'},
#  {'average_rating': '3.94',
#   'author_id': '344352',
#   'text_reviews_count': '627',
#   'name': 'Kim Wilkins',
#   'ratings_count': '5602'},
#  {'average_rating': '3.77',
#   'author_id': '5137727',
#   'text_reviews_count': '142',
#   'name': 'Julia Hughes',
#   'ratings_count': '560'},
#  {'average_rating': '4.14',
#   'author_id': '1654',
#   'text_reviews_count': '106290',
#   'name': 'Terry Pratchett',
#   'ratings_count': '3267646'},
#  {'average_rating': '3.98',
#   'author_id': '2785687',
#   'text_reviews_count': '353',
#   'name': 'Piotr W. Cholewa',
#   'ratings_count': '12700'},
#  {'average_rating': '3.83',
#   'author_id': '31227',
#   'text_reviews_count': '982',
#   'name': 'Kayla Perrin',
#   'ratings_count': '9363'},
#  {'average_rating': '3.94',
#   'author_id': '175979',
#   'text_reviews_count': '130',
#   'name': 'Alan Dundes',
#   'ratings_count': '1711'},
#  {'average_rating': '3.85',
#   'author_id': '7020049',
#   'text_reviews_count': '1',
#   'name': 'Francesco Bertolino',
#   'ratings_count': '55'},
#  {'average_rating': '4.05',
#   'author_id': '15058478',
#   'text_reviews_count': '135',
#   'name': 'Jacque Stevens',
#   'ratings_count': '180'},
#  {'average_rating': '4.15',
#   'author_id': '4610',
#   'text_reviews_count': '32142',
#   'name': 'John Sandford',
#   'ratings_count': '665039'},
#  {'average_rating': '4.24',
#   'author_id': '250363',
#   'text_reviews_count': '186',
#   'name': 'Antonia Barber',
#   'ratings_count': '2020'},
#  {'average_rating': '3.94',
#   'author_id': '45642',
#   'text_reviews_count': '1083',
#   'name': 'Meilo So',
#   'ratings_count': '4271'},
#  {'average_rating': '3.52',
#   'author_id': '6965675',
#   'text_reviews_count': '161',
#   'name': 'Katelyn Skye',
#   'ratings_count': '1749'},
#  {'average_rating': '3.82',
#   'author_id': '358318',
#   'text_reviews_count': '8',
#   'name': 'Linda S. Budd',
#   'ratings_count': '62'},
#  {'average_rating': '4.27',
#   'author_id': '738091',
#   'text_reviews_count': '1380',
#   'name': 'P.J. Lynch',
#   'ratings_count': '19776'},
#  {'average_rating': '3.98',
#   'author_id': '8445092',
#   'text_reviews_count': '134',
#   'name': 'T.M. Mendes',
#   'ratings_count': '1742'},
#  {'average_rating': '4.13',
#   'author_id': '13557729',
#   'text_reviews_count': '9238',
#   'name': 'Daniel Abraham',
#   'ratings_count': '167102'},
#  {'average_rating': '4.37',
#   'author_id': '346732',
#   'text_reviews_count': '164622',
#   'name': 'George R.R. Martin',
#   'ratings_count': '4277240'},
#  {'average_rating': '4.09',
#   'author_id': '14653917',
#   'text_reviews_count': '4',
#   'name': 'Michael Forcier',
#   'ratings_count': '11'},
#  {'average_rating': '4.10',
#   'author_id': '30195',
#   'text_reviews_count': '2535',
#   'name': 'Mario Benedetti',
#   'ratings_count': '32727'},
#  {'average_rating': '3.67',
#   'author_id': '41000',
#   'text_reviews_count': '17',
#   'name': 'Barbara Knox',
#   'ratings_count': '60'},
#  {'average_rating': '3.45',
#   'author_id': '104702',
#   'text_reviews_count': '37',
#   'name': 'Don L. Curry',
#   'ratings_count': '232'},
#  {'average_rating': '3.52',
#   'author_id': '8118587',
#   'text_reviews_count': '221',
#   'name': 'April  Andrews',
#   'ratings_count': '1879'},
#  {'average_rating': '4.16',
#   'author_id': '1425903',
#   'text_reviews_count': '735',
#   'name': 'Andre Dubus',
#   'ratings_count': '8796'},
#  ...]

# %%
authors_df = pd.DataFrame.from_dict(book_authors_data).drop('name', axis=1)

# %% [markdown]
# ### Generos

# %%
genres_df = pd.DataFrame.from_dict(book_genres_data)
genres_df['genres_mode'] = genres_df['genres'].apply(lambda d: max(d, key=lambda k: d[k]) if len(d)!=0 else 'No genre')
genres_df['genres_mode_conf'] = genres_df['genres'].apply(lambda d: max(d.values())/sum(d.values()) 
                                                          if ((len(d)!=0) and (sum(d.values())!=0)) else 0)

# %%
genres_df
# Out:
#          book_id                                             genres  \
# 0        5333265      {'history, historical fiction, biography': 1}
# 1        1333909  {'fiction': 219, 'history, historical fiction,...
# 2        7327624  {'fantasy, paranormal': 31, 'fiction': 8, 'mys...
# 3        6066819  {'fiction': 555, 'romance': 23, 'mystery, thri...
# 4         287140                                 {'non-fiction': 3}
# ...          ...                                                ...
# 99996   24679885  {'young-adult': 42, 'mystery, thriller, crime'...
# 99997   27883170  {'fantasy, paranormal': 60, 'fiction': 16, 'yo...
# 99998   35992614                                     {'romance': 2}
# 99999    8713454  {'fiction': 88, 'history, historical fiction, ...
# 100000   6474616  {'comics, graphic': 201, 'fiction': 33, 'child...
#
#                                    genres_mode  genres_mode_conf
# 0       history, historical fiction, biography          1.000000
# 1                                      fiction          0.977679
# 2                          fantasy, paranormal          0.756098
# 3                                      fiction          0.943878
# 4                                  non-fiction          1.000000
# ...                                        ...               ...
# 99996                              young-adult          0.420000
# 99997                      fantasy, paranormal          0.659341
# 99998                                  romance          1.000000
# 99999                                  fiction          0.478261
# 100000                         comics, graphic          0.747212
#
# [100001 rows x 4 columns]

# %%
genres_df.genres_mode.unique()
# Out:
# array(['history, historical fiction, biography', 'fiction',
#        'fantasy, paranormal', 'non-fiction', 'romance',
#        'mystery, thriller, crime', 'No genre', 'children', 'poetry',
#        'young-adult', 'comics, graphic'], dtype=object)

# %%
genres_df_fil = genres_df[['book_id', 'genres_mode', 'genres_mode_conf']]

# %% [markdown]
# ### Work

# %%
work_df = pd.DataFrame.from_dict(book_work_data)

# %%
work_df
# Out:
#        books_count reviews_count original_publication_month  \
# 0                1             6                          8
# 1               22         10162
# 2                2           268
# 3               38         89252                          7
# 4                2            49
# ...            ...           ...                        ...
# 99996           46          1214
# 99997            4            23                          5
# 99998           35          1077
# 99999            9          2023                         11
# 100000          46        117180
#
#        default_description_language_code text_reviews_count best_book_id  \
# 0                                                         1      5333265
# 1                                                       741        25717
# 2                                                         7      7327624
# 3                                                      3504      6066819
# 4                                                         5       287140
# ...                                  ...                ...          ...
# 99996                                                    75      1094330
# 99997                                                     3       892238
# 99998                                                    45      1094332
# 99999                                                    85           83
# 100000                                                 3478       306654
#
#        original_publication_year  \
# 0                           1984
# 1                           2001
# 2                           1987
# 3                           2009
# 4                           1990
# ...                          ...
# 99996                       1926
# 99997                       1976
# 99998                       1928
# 99999                       1986
# 100000                      1984
#
#                                            original_title  \
# 0                            W. C. Fields: A Life on Film
# 1                                             Good Harbor
# 2
# 3                                    Best Friends Forever
# 4       Runic Astrology: Starcraft and Timekeeping in ...
# ...                                                   ...
# 99996                              The Benson Murder Case
# 99997                      The Diary of Samuel Pepys 1668
# 99998                              The Bishop Murder Case
# 99999                              Rising from the Plains
# 100000                                    Cold Sassy Tree
#
#                                               rating_dist  \
# 0                             5:1|4:1|3:1|2:0|1:0|total:3
# 1              5:517|4:1787|3:2763|2:966|1:196|total:6229
# 2                        5:49|4:58|3:26|2:5|1:3|total:141
# 3        5:9152|4:16855|3:19507|2:6210|1:1549|total:53273
# 4                            5:6|4:1|3:3|2:3|1:2|total:15
# ...                                                   ...
# 99996                5:83|4:157|3:182|2:51|1:19|total:492
# 99997                        5:5|4:5|3:5|2:0|1:0|total:15
# 99998               5:116|4:166|3:131|2:50|1:33|total:496
# 99999               5:504|4:478|3:176|2:24|1:8|total:1190
# 100000  5:30277|4:31848|3:18576|2:4010|1:1435|total:86146
#
#        default_chaptering_book_id original_publication_day  \
# 0
# 1
# 2
# 3                                                       14
# 4
# ...                           ...                      ...
# 99996
# 99997                                                   11
# 99998
# 99999                                                   17
# 100000
#
#        original_language_id ratings_count media_type ratings_sum  work_id
# 0                                       3       book          12  5400751
# 1                                    6229       book       20150  1323437
# 2                                     141       book         568  8948723
# 3                                   53273       book      185670  6243154
# 4                                      15       book          51   278577
# ...                     ...           ...        ...         ...      ...
# 99996                                 492       book        1710  1081147
# 99997                                  15       book          60   877477
# 99998                                 496       book        1770  1081149
# 99999                                1190       book        5016  1391039
# 100000                              86146       book      343960  1187268
#
# [100001 rows x 16 columns]

# %% [markdown]
# ## Union

# %%
aux_df = books_df.merge(genres_df_fil, how='left', on='book_id').merge(authors_df, how='left', on='author_id')

aux_df['book_id'] = aux_df['book_id'].apply(lambda x: str(x))
interactions['book_id'] = interactions['book_id'].apply(lambda x: str(x))
whole_data_df = interactions.merge(aux_df, how='left', on='book_id')

# %%
whole_data_df
# Out:
#        user_id book_id  is_read  rating  is_reviewed is_ebook  \
# 0            0     948        1       5            0      NaN
# 1            0     947        1       5            1      NaN
# 2            0     946        1       5            0      NaN
# 3            0     945        1       5            0      NaN
# 4            0     944        1       5            0      NaN
# ...        ...     ...      ...     ...          ...      ...
# 99995      227     882        1       3            0      NaN
# 99996      227   59168        1       3            0      NaN
# 99997      227   24428        1       3            0      NaN
# 99998      227   59167        1       2            0      NaN
# 99999      227   59166        1       1            0      NaN
#
#       average_rating_book num_pages authors publication_year  \
# 0                     NaN       NaN     NaN              NaN
# 1                     NaN       NaN     NaN              NaN
# 2                     NaN       NaN     NaN              NaN
# 3                     NaN       NaN     NaN              NaN
# 4                     NaN       NaN     NaN              NaN
# ...                   ...       ...     ...              ...
# 99995                 NaN       NaN     NaN              NaN
# 99996                 NaN       NaN     NaN              NaN
# 99997                 NaN       NaN     NaN              NaN
# 99998                 NaN       NaN     NaN              NaN
# 99999                 NaN       NaN     NaN              NaN
#
#       text_reviews_count_book ratings_count_book author_id genres_mode  \
# 0                         NaN                NaN       NaN         NaN
# 1                         NaN                NaN       NaN         NaN
# 2                         NaN                NaN       NaN         NaN
# 3                         NaN                NaN       NaN         NaN
# 4                         NaN                NaN       NaN         NaN
# ...                       ...                ...       ...         ...
# 99995                     NaN                NaN       NaN         NaN
# 99996                     NaN                NaN       NaN         NaN
# 99997                     NaN                NaN       NaN         NaN
# 99998                     NaN                NaN       NaN         NaN
# 99999                     NaN                NaN       NaN         NaN
#
#        genres_mode_conf average_rating text_reviews_count ratings_count
# 0                   NaN            NaN                NaN           NaN
# 1                   NaN            NaN                NaN           NaN
# 2                   NaN            NaN                NaN           NaN
# 3                   NaN            NaN                NaN           NaN
# 4                   NaN            NaN                NaN           NaN
# ...                 ...            ...                ...           ...
# 99995               NaN            NaN                NaN           NaN
# 99996               NaN            NaN                NaN           NaN
# 99997               NaN            NaN                NaN           NaN
# 99998               NaN            NaN                NaN           NaN
# 99999               NaN            NaN                NaN           NaN
#
# [100000 rows x 18 columns]

# %%
aux_df
# Out:
#          book_id is_ebook average_rating_book num_pages  \
# 0        5333265    false                4.00       256
# 1        1333909    false                3.23
# 2        7327624    false                4.03       600
# 3        6066819    false                3.49       368
# 4         287140    false                3.40
# ...          ...      ...                 ...       ...
# 99996   24679885     true                4.19
# 99997   27883170     true                3.51        33
# 99998   35992614     true                4.33
# 99999    8713454    false                3.33       358
# 100000   6474616    false                3.51        44
#
#                                         authors publication_year  \
# 0         [{'author_id': '604031', 'role': ''}]             1984
# 1         [{'author_id': '626222', 'role': ''}]             2001
# 2          [{'author_id': '10333', 'role': ''}]             1987
# 3           [{'author_id': '9212', 'role': ''}]             2009
# 4         [{'author_id': '149918', 'role': ''}]
# ...                                         ...              ...
# 99996      [{'author_id': '26372', 'role': ''}]
# 99997     [{'author_id': '175855', 'role': ''}]             2016
# 99998   [{'author_id': '15428911', 'role': ''}]             2017
# 99999     [{'author_id': '385819', 'role': ''}]
# 100000   [{'author_id': '2802356', 'role': ''}]
#
#        text_reviews_count_book ratings_count_book author_id  \
# 0                            1                  3    604031
# 1                            6                 10    626222
# 2                            7                140     10333
# 3                         3282              51184      9212
# 4                            5                 15    149918
# ...                        ...                ...       ...
# 99996                        3                 95     26372
# 99997                       80                276    175855
# 99998                       10                 15  15428911
# 99999                       66                310    385819
# 100000                       2                 53   2802356
#
#                                    genres_mode  genres_mode_conf  \
# 0       history, historical fiction, biography          1.000000
# 1                                      fiction          0.977679
# 2                          fantasy, paranormal          0.756098
# 3                                      fiction          0.943878
# 4                                  non-fiction          1.000000
# ...                                        ...               ...
# 99996                              young-adult          0.420000
# 99997                      fantasy, paranormal          0.659341
# 99998                                  romance          1.000000
# 99999                                  fiction          0.478261
# 100000                         comics, graphic          0.747212
#
#        average_rating text_reviews_count ratings_count
# 0                3.98                  7            49
# 1                4.08              28716        546796
# 2                3.92               5075        122118
# 3                3.68              36262        888522
# 4                3.82                 96          1740
# ...               ...                ...           ...
# 99996            3.94              28714        568158
# 99997            3.76              24392        371713
# 99998            4.04                 65           224
# 99999            3.52                189           796
# 100000           4.01               5396        227167
#
# [100001 rows x 14 columns]

# %% [markdown]
# # Model

# %%
from surprise.prediction_algorithms.knns import KNNWithMeans

from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
reader = Reader(rating_scale=(1, 5))

# %%
ibcf_author_df = whole_data_df[['user_id', 'author_id','rating']]
ibcf_author_df.columns = ['user_id', 'author_id', 'raw_ratings']
ibcf_books_df = whole_data_df[['user_id', 'book_id','rating']]
ibcf_books_df.columns = ['user_id','book_id' , 'raw_ratings']
ibcf_genres_df = whole_data_df[['user_id', 'genres_mode','rating']]
ibcf_genres_df.columns = ['user_id','genres_mode' , 'raw_ratings']
ibcf_author_df = Dataset.load_from_df(ibcf_author_df, reader)
ibcf_books_df = Dataset.load_from_df(ibcf_books_df, reader)
ibcf_genres_df = Dataset.load_from_df(ibcf_genres_df, reader)

# %%
# We'll use the famous SVD algorithm.
algo_authors = KNNWithMeans(k=5)
algo_genres = KNNWithMeans(k=5)
algo_books = KNNWithMeans(k=5)
# Run 5-fold cross-validation and print results
cross_validate(algo_authors, ibcf_author_df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
cross_validate(algo_genres, ibcf_genres_df, measures=['RMSE', 'MAE'], cv=5, verbose=True)
cross_validate(algo_books, ibcf_books_df, measures=['RMSE', 'MAE'], cv=5, verbose=True)

# %% [markdown]
# ### IBCF genres

# %% [markdown]
# ### IBCF authors

# %% [markdown]
# ### IBCF books
